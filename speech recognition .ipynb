# %%
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from imutils import paths
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
from tqdm import tqdm
from scipy import signal
from scipy.io import wavfile
import matplotlib.pyplot as plt

# %%
audios_dir = r'C:/Users/Chaitanya/Desktop/dsp/tensorflow-speech-recognition-challenge/train/audio/'

# %%
words=["yes", "no", "up", "down", "left", "right", "on", "off", "stop", "go"]

# %%
sample_rate, samples = wavfile.read(r'C:/Users/Chaitanya/Desktop/dsp/tensorflow-speech-recognition-challenge/train/audio/yes/00f0204f_nohash_1.wav')
frequencies, times, spectrogram = signal.spectrogram(samples, sample_rate)

plt.figure(figsize=(30,8))
plt.pcolormesh(times, frequencies, spectrogram)
plt.imshow(spectrogram)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
data = []
labels = []
dirs = os.listdir(audios_dir)
for d in dirs:
    if d in words:
        print(d)
        files = os.listdir(os.path.join(audios_dir,d))
        audios = [f for f in files if f.endswith('.wav')]
        for file in audios:
            # load the image, swap color channels, and resize it to be a fixed
            # 224x224 pixels while ignoring aspect ratio
            #file = audios[i]
            sample_rate, samples = wavfile.read(os.path.join(audios_dir,d,file))
            frequencies, times, spectrogram = signal.spectrogram(samples, sample_rate)

            # convert the image data to NumPy arrays while scaling the pixel
            # intensities to the range [0, 255]
            #image = np.array(image)/255.0
            
            # update the data and labels lists, respectively
            if spectrogram.shape[0] >= 128 and spectrogram.shape[1] >=48:
                data.append(spectrogram[:128,:48])
                labels.append(d)
            #else:
             #   print(spectrogram.shape)
# Out:
# down
# go
# left
# no
# off
# on
# right
# stop
# up
# yes

# %%
data = np.array(data)

data.shape
# Out:
# (23455, 128, 48)

# %%
values,count = np.unique(labels,return_counts=True)

# %%
import matplotlib.pyplot as plt
#plot
plt.figure(figsize=(10,5))
index = np.arange(len(words))
plt.bar(index, count)
plt.xlabel('Commands', fontsize=12)
plt.ylabel('No of samples', fontsize=12)
plt.xticks(index, words, fontsize=15, rotation=60)
plt.title('No. of samples for each command')
plt.show()

# %%
labels_backup = labels
# convert the labels to NumPy arrays while scaling the pixel
labels = np.array(labels)

# %%
# perform one-hot encoding on the labels
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
ls = le.fit_transform(labels)

# %%
labels_categoricals = to_categorical(ls)
labels_categoricals.shape
# Out:
# (23455, 10)

# %%
# partition the data into training,cross-validation and testing splits using 60%,20% and 20% of data
(trainX, testX, trainY, testY) = train_test_split(data, labels_categoricals,test_size=0.20, stratify=labels_categoricals, random_state=42)
(trainX, cvX, trainY, cvY) = train_test_split(trainX, trainY,test_size=0.25, stratify=trainY, random_state=42)

# %%
del data
del labels_categoricals
print("Train data size : ",trainX.shape)
print("Cross-Validation data size : ",cvX.shape)
print("Test data size : ",testX.shape)
# Out:
# Train data size :  (14073, 128, 48)
# Cross-Validation data size :  (4691, 128, 48)
# Test data size :  (4691, 128, 48)

# %%
from keras import backend as K

# input image dimensions
img_rows, img_cols = 128, 48

if K.image_data_format() == 'channels_first':
    trainX = trainX.reshape(trainX.shape[0], 1, img_rows, img_cols)
    testX = testX.reshape(testX.shape[0], 1, img_rows, img_cols)
    cvX = cvX.reshape(cvX.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    trainX = trainX.reshape(trainX.shape[0],img_rows, img_cols,1)
    testX = testX.reshape(testX.shape[0],img_rows, img_cols,1)
    cvX = cvX.reshape(cvX.shape[0],img_rows, img_cols,1)
    input_shape = (img_rows, img_cols,1)

# %%
print("Number of training examples :", trainX.shape[0], "and each image is of shape :",trainX.shape)
print("Number of cross validation examples :", cvX.shape[0], "and each image is of shape :",cvX.shape)
print("Number of testing examples :", testX.shape[0], "and each image is of shape :",testX.shape)
# Out:
# Number of training examples : 14073 and each image is of shape : (14073, 128, 48, 1)
# Number of cross validation examples : 4691 and each image is of shape : (4691, 128, 48, 1)
# Number of testing examples : 4691 and each image is of shape : (4691, 128, 48, 1)

# %%
#initialize the initial learning rate, number of epochs to train for and batch size
INIT_LR = 1e-3
EPOCHS = 50
batch_size = 64
num_class = 10
#input_shape = (224,224,3) #(513, 800, 3)

# %%
from keras.models import Sequential 
from keras.layers import Dense, Activation
from keras.layers import Dropout,Flatten
from keras.layers.normalization import BatchNormalization
from keras.layers import Conv2D, MaxPooling2D

# %%
model = Sequential()
model.add(Conv2D(8, kernel_size=(2, 2),padding='same',activation='relu',input_shape=input_shape))
model.add(Conv2D(16, kernel_size=(2, 2),padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Conv2D(32, kernel_size=(2, 2),padding='same',activation='relu'))
model.add(Conv2D(64, kernel_size=(2, 2),padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Conv2D(128, kernel_size=(2, 2),padding='same',activation='relu'))
model.add(Conv2D(256, kernel_size=(2, 2),padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_class, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 48, 8)        40
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 48, 16)       528
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 24, 16)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 24, 16)        64
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 24, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 24, 32)        2080
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 24, 64)        8256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 12, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 12, 64)        256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 12, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 12, 128)       32896
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 12, 256)       131328
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 6, 256)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 6, 256)        1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 6, 256)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 24576)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               6291712
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 6,470,754
# Trainable params: 6,470,082
# Non-trainable params: 672
# _________________________________________________________________

# %%
#from tensorflow.keras.optimizers import Adam
#opt = Adam(lr=INIT_LR)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
from keras.callbacks import EarlyStopping, ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25, min_delta=0.0001) 
mc = ModelCheckpoint('best_model.hdf5', monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
history = model.fit(trainX, trainY, batch_size=batch_size, epochs=EPOCHS, verbose=1, callbacks=[es,mc],validation_data=(cvX, cvY))
# Out:
# Epoch 1/50
# 220/220 [==============================] - ETA: 0s - loss: 2.6270 - accuracy: 0.1130WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 184s 836ms/step - loss: 2.6270 - accuracy: 0.1130 - val_loss: 2.3054 - val_accuracy: 0.1102
# Epoch 2/50
# 220/220 [==============================] - ETA: 0s - loss: 2.2866 - accuracy: 0.1270WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 181s 823ms/step - loss: 2.2866 - accuracy: 0.1270 - val_loss: 2.2842 - val_accuracy: 0.1337
# Epoch 3/50
# 220/220 [==============================] - ETA: 0s - loss: 2.2344 - accuracy: 0.1492WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 183s 833ms/step - loss: 2.2344 - accuracy: 0.1492 - val_loss: 2.2128 - val_accuracy: 0.1789
# Epoch 4/50
# 220/220 [==============================] - ETA: 0s - loss: 2.1996 - accuracy: 0.1730WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 185s 842ms/step - loss: 2.1996 - accuracy: 0.1730 - val_loss: 10.9323 - val_accuracy: 0.1059
# Epoch 5/50
# 220/220 [==============================] - ETA: 0s - loss: 2.1355 - accuracy: 0.1911WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 188s 856ms/step - loss: 2.1355 - accuracy: 0.1911 - val_loss: 3.8020 - val_accuracy: 0.1584
# Epoch 6/50
# 220/220 [==============================] - ETA: 0s - loss: 2.0691 - accuracy: 0.2076WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 186s 846ms/step - loss: 2.0691 - accuracy: 0.2076 - val_loss: 1.9880 - val_accuracy: 0.2739
# Epoch 7/50
# 220/220 [==============================] - ETA: 0s - loss: 2.0020 - accuracy: 0.2354WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 186s 845ms/step - loss: 2.0020 - accuracy: 0.2354 - val_loss: 4.8149 - val_accuracy: 0.1418
# Epoch 8/50
# 220/220 [==============================] - ETA: 0s - loss: 1.9600 - accuracy: 0.2535WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] -
ARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 175s 798ms/step - loss: 0.8265 - accuracy: 0.6991 - val_loss: 0.9918 - val_accuracy: 0.6843
# Epoch 38/50
# 220/220 [==============================] - ETA: 0s - loss: 0.8042 - accuracy: 0.7110WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 175s 798ms/step - loss: 0.8042 - accuracy: 0.7110 - val_loss: 1.4147 - val_accuracy: 0.4963
# Epoch 39/50
# 220/220 [==============================] - ETA: 0s - loss: 0.7842 - accuracy: 0.7186WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 175s 797ms/step - loss: 0.7842 - accuracy: 0.7186 - val_loss: 1.0961 - val_accuracy: 0.6436
# Epoch 40/50
# 220/220 [==============================] - ETA: 0s - loss: 0.7811 - accuracy: 0.7175WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 175s 797ms/step - loss: 0.7811 - accuracy: 0.7175 - val_loss: 0.9130 - val_accuracy: 0.7111
# Epoch 41/50
# 220/220 [==============================] - ETA: 0s - loss: 0.7792 - accuracy: 0.7255WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 176s 800ms/step - loss: 0.7792 - accuracy: 0.7255 - val_loss: 1.2929 - val_accuracy: 0.5415
# Epoch 42/50
# 220/220 [==============================] - ETA: 0s - loss: 0.7406 - accuracy: 0.7333WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 181s 824ms/step - loss: 0.7406 - accuracy: 0.7333 - val_loss: 1.1827 - val_accuracy: 0.6231
# Epoch 43/50
# 220/220 [==============================] - ETA: 0s - loss: 0.7489 - accuracy: 0.7310WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 175s 797ms/step - loss: 0.7489 - accuracy: 0.7310 - val_loss: 1.1527 - val_accuracy: 0.6026
# Epoch 44/50
# 220/220 [==============================] - ETA: 0s - loss: 0.7210 - accuracy: 0.7482WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 176s 798ms/step - loss: 0.7210 - accuracy: 0.7482 - val_loss: 0.9411 - val_accuracy: 0.6868
# Epoch 45/50
# 220/220 [==============================] - ETA: 0s - loss: 0.7206 - accuracy: 0.7479WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 175s 796ms/step - loss: 0.7206 - accuracy: 0.7479 - val_loss: 0.9634 - val_accuracy: 0.6643
# Epoch 46/50
# 220/220 [==============================] - ETA: 0s - loss: 0.6954 - accuracy: 0.7539WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 175s 796ms/step - loss: 0.6954 - accuracy: 0.7539 - val_loss: 1.0075 - val_accuracy: 0.6547
# Epoch 47/50
# 220/220 [==============================] - ETA: 0s - loss: 0.6885 - accuracy: 0.7536WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 179s 814ms/step - loss: 0.6885 - accuracy: 0.7536 - val_loss: 1.1374 - val_accuracy: 0.6353
# Epoch 48/50
# 220/220 [==============================] - ETA: 0s - loss: 0.6904 - accuracy: 0.7588WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 181s 824ms/step - loss: 0.6904 - accuracy: 0.7588 - val_loss: 1.0916 - val_accuracy: 0.6461
# Epoch 49/50
# 220/220 [==============================] - ETA: 0s - loss: 0.6585 - accuracy: 0.7703WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 187s 849ms/step - loss: 0.6585 - accuracy: 0.7703 - val_loss: 0.9160 - val_accuracy: 0.7024
# Epoch 50/50
# 220/220 [==============================] - ETA: 0s - loss: 0.6619 - accuracy: 0.7670WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 220/220 [==============================] - 188s 856ms/step - loss: 0.6619 - accuracy: 0.7670 - val_loss: 1.0716 - val_accuracy: 0.6382

# %%
# plot the training loss
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
#plt.plot(np.arange(0, N), history.history["accuracy"], label="train_acc")
#plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_acc")
plt.title("Train/CV Loss ")
plt.xlabel("Number of epochs")
plt.ylabel("Loss")
plt.legend(loc="lower left")

# %%
# plot the training accuracy
N = EPOCHS
#plt.style.use("ggplot")
plt.figure()
#plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
#plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_acc")
plt.title("Train and Cross validation accuracy ")
plt.xlabel("Number of epochs")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")

# %%
best_acc = max(history.history["val_accuracy"])
best_acc*100
# Out:
# 71.66915535926819

# %%
# make predictions on the testing set
predIdxs = model.predict(testX, batch_size=batch_size)
# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
predIdxs = np.argmax(predIdxs, axis=1)

# %%
def plot_Confusion_Matrix(actual_labels,predict_labels,title):
    """This function plot the confusion matrix"""
    # Reference : https://seaborn.pydata.org/generated/seaborn.heatmap.html
    cm = confusion_matrix(actual_labels, predict_labels)
    classNames = words
    cm_data = pd.DataFrame(cm,index = classNames,
                  columns = classNames)
    plt.figure(figsize = (8,8))
    sns.heatmap(cm_data, annot=True,fmt="d")
    plt.title(title)
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
import pandas as pd
import seaborn as sns
from sklearn.metrics import confusion_matrix

plot_Confusion_Matrix(testY.argmax(axis=1), predIdxs,"Confusion Matrix")
